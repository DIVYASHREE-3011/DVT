# %%
import pandas as pd

df=pd.read_csv("C:/Users/svdiv/Downloads/Dataset of Diabetes .csv")
print(df.head())
# Out:
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
num_cols = df.select_dtypes(include='number').columns

df[num_cols] = df[num_cols].fillna(df[num_cols].mean())

print(df.isnull().sum())
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          0
# Urea         0
# Cr           0
# HbA1c        0
# Chol         0
# TG           0
# HDL          0
# LDL          0
# VLDL         0
# BMI          0
# CLASS        0
# dtype: int64

# %%
print("Duplicates:", df.duplicated().sum())

df.drop_duplicates(inplace=True)

print(df)
# Out:
# Duplicates: 0
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# 1    23.0     N
# 2    24.0     N
# 3    24.0     N
# 4    21.0     N
# ..    ...   ...
# 995  30.0     Y
# 996  37.2    Y
# 997  27.4    Y
# 998  40.5    Y
# 999  33.0    Y
#
# [1000 rows x 14 columns]

# %%
Q1 = df['BMI'].quantile(0.25)
Q3 = df['BMI'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df['BMI'] < lower) | (df['BMI'] > upper)]

print(outliers)
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 183  108      24007      M   38  4.00  67   10.2   5.2  2.0  1.1  3.2  14.0
# 188  666      66456      M   38  4.00  67   10.2   5.2  2.0  1.1  3.2  14.0
# 698  641      86422      M   55  3.66  60   10.8   7.3  1.6  1.2  5.5  11.3
#
#        BMI CLASS
# 183  47.00     Y
# 188  47.00     Y
# 698  47.75     Y

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df[['AGE', 'Urea', 'Cr', 'HbA1c', 'Chol',
    'TG', 'HDL', 'LDL', 'VLDL', 'BMI']] = scaler.fit_transform(
    df[['AGE', 'Urea', 'Cr', 'HbA1c', 'Chol',
        'TG', 'HDL', 'LDL', 'VLDL', 'BMI']]
)

print(df.head())
# Out:
#     ID  No_Pation Gender       AGE      Urea        Cr     HbA1c      Chol  \
# 0  502      17975      F  0.508475  0.109375  0.050378  0.264901  0.407767
# 1  735      34221      M  0.101695  0.104167  0.070529  0.264901  0.359223
# 2  420      47975      F  0.508475  0.109375  0.050378  0.264901  0.407767
# 3  680      87656      F  0.508475  0.109375  0.050378  0.264901  0.407767
# 4  504      34223      M  0.220339  0.171875  0.050378  0.264901  0.475728
#
#          TG       HDL       LDL      VLDL       BMI CLASS
# 0  0.044444  0.226804  0.114583  0.011461  0.173913     N
# 1  0.081481  0.092784  0.187500  0.014327  0.139130     N
# 2  0.044444  0.226804  0.114583  0.011461  0.173913     N
# 3  0.044444  0.226804  0.114583  0.011461  0.173913     N
# 4  0.051852  0.061856  0.177083  0.008596  0.069565     N

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

df['Gender'] = encoder.fit_transform(df['Gender'])
df['CLASS'] = encoder.fit_transform(df['CLASS'])

print(df.head())
# Out:
#     ID  No_Pation  Gender       AGE      Urea        Cr     HbA1c      Chol  \
# 0  502      17975       0  0.508475  0.109375  0.050378  0.264901  0.407767
# 1  735      34221       1  0.101695  0.104167  0.070529  0.264901  0.359223
# 2  420      47975       0  0.508475  0.109375  0.050378  0.264901  0.407767
# 3  680      87656       0  0.508475  0.109375  0.050378  0.264901  0.407767
# 4  504      34223       1  0.220339  0.171875  0.050378  0.264901  0.475728
#
#          TG       HDL       LDL      VLDL       BMI  CLASS
# 0  0.044444  0.226804  0.114583  0.011461  0.173913      0
# 1  0.081481  0.092784  0.187500  0.014327  0.139130      0
# 2  0.044444  0.226804  0.114583  0.011461  0.173913      0
# 3  0.044444  0.226804  0.114583  0.011461  0.173913      0
# 4  0.051852  0.061856  0.177083  0.008596  0.069565      0

# %%
df = pd.get_dummies(df, columns=['Gender'], dtype=int)

print(df.head())
# Out:
#     ID  No_Pation       AGE      Urea        Cr     HbA1c      Chol        TG  \
# 0  502      17975  0.508475  0.109375  0.050378  0.264901  0.407767  0.044444
# 1  735      34221  0.101695  0.104167  0.070529  0.264901  0.359223  0.081481
# 2  420      47975  0.508475  0.109375  0.050378  0.264901  0.407767  0.044444
# 3  680      87656  0.508475  0.109375  0.050378  0.264901  0.407767  0.044444
# 4  504      34223  0.220339  0.171875  0.050378  0.264901  0.475728  0.051852
#
#         HDL       LDL      VLDL       BMI  CLASS  Gender_0  Gender_1  Gender_2
# 0  0.226804  0.114583  0.011461  0.173913      0         1         0         0
# 1  0.092784  0.187500  0.014327  0.139130      0         0         1         0
# 2  0.226804  0.114583  0.011461  0.173913      0         1         0         0
# 3  0.226804  0.114583  0.011461  0.173913      0         1         0         0
# 4  0.061856  0.177083  0.008596  0.069565      0         0         1         0
